# %% [markdown]
# <a href="https://colab.research.google.com/github/Seanatist/Customer_Churn_Demo/blob/main/CustomerChurnDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone repo
# !git clone https://github.com/Seanatist/Customer_Churn_Demo.git
# %cd Customer_Churn_Demo
# Extra: tunnel library to expose Streamlit
# !pip install pyngrok
# Out:
# Cloning into 'Customer_Churn_Demo'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 569.11 KiB | 499.00 KiB/s, done.
# /content/Customer_Churn_Demo/Customer_Churn_Demo
# ...

# %%
# Install dependencies (includes Streamlit)
# !pip install -r requirements.txt

# %%
import os
from pyngrok import ngrok

# Paste your token here
NGROK_AUTH_TOKEN = "3Aw2YTOuuVgroMIMhNU1rTiYrhi_7FEkqikL9ki4ZykZMwcUS"
os.environ["3Aw2YTOuuVgroMIMhNU1rTiYrhi_7FEkqikL9ki4ZykZMwcUS"] = NGROK_AUTH_TOKEN
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# %%
# This will generate encoders.pkl and customer_churn_model.pkl
# !python CustomerChurn.py
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
import threading
import time
from pyngrok import ngrok

# Kill any existing tunnels
ngrok.kill()

# Start a public URL for port 8501
public_url = ngrok.connect(8501, "http")
print("Public URL:", public_url)

def run_streamlit():
    # !streamlit run customer_churn_app.py --server.port 8501 --server.address 0.0.0.0

# Run Streamlit in background thread
thread = threading.Thread(target=run_streamlit, daemon=True)
thread.start()

# Give Streamlit a few seconds to start
time.sleep(10)
print("Streamlit should now be running at:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://apolitically-irrepleviable-tristan.ngrok-free.dev" -> "http://localhost:8501"
#
# ...
#
# 2026-03-14 12:36:05.013 Port 8501 is not available
# Streamlit should now be running at: NgrokTunnel: "https://apolitically-irrepleviable-tristan.ngrok-free.dev" -> "http://localhost:8501"
